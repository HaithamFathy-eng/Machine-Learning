# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\PC\Downloads\Haitham Fathy - Student_performance_data _.csv")

# %%
df.head()
# Out:
#    StudentID  Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  \
# 0       1001   17       1          0                  2        19.833723
# 1       1002   18       0          0                  1        15.408756
# 2       1003   15       0          2                  3         4.210570
# 3       1004   17       1          0                  3        10.028829
# 4       1005   17       1          0                  2         4.672495
#
#    Absences  Tutoring  ParentalSupport  Extracurricular  Sports  Music  \
# 0         7         1                2                0       0      1
# 1         0         0                1                0       0      0
# 2        26         0                2                0       0      0
# 3        14         0                3                1       0      0
# 4        17         1                3                0       0      0
#
#    Volunteering       GPA  GradeClass
# 0             0  2.929196         2.0
# ...

# %%
df.describe()
# Out:
#          StudentID          Age       Gender    Ethnicity  ParentalEducation  \
# count  2392.000000  2392.000000  2392.000000  2392.000000        2392.000000
# mean   2196.500000    16.468645     0.510870     0.877508           1.746237
# std     690.655244     1.123798     0.499986     1.028476           1.000411
# min    1001.000000    15.000000     0.000000     0.000000           0.000000
# 25%    1598.750000    15.000000     0.000000     0.000000           1.000000
# 50%    2196.500000    16.000000     1.000000     0.000000           2.000000
# 75%    2794.250000    17.000000     1.000000     2.000000           2.000000
# max    3392.000000    18.000000     1.000000     3.000000           4.000000
#
#        StudyTimeWeekly     Absences     Tutoring  ParentalSupport  \
# count      2392.000000  2392.000000  2392.000000      2392.000000
# mean          9.771992    14.541388     0.301421         2.122074
# std           5.652774     8.467417     0.458971         1.122813
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2392 entries, 0 to 2391
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   StudentID          2392 non-null   int64
#  1   Age                2392 non-null   int64
#  2   Gender             2392 non-null   int64
#  3   Ethnicity          2392 non-null   int64
#  4   ParentalEducation  2392 non-null   int64
#  5   StudyTimeWeekly    2392 non-null   float64
#  6   Absences           2392 non-null   int64
#  7   Tutoring           2392 non-null   int64
#  8   ParentalSupport    2392 non-null   int64
#  9   Extracurricular    2392 non-null   int64
#  10  Sports             2392 non-null   int64
#  11  Music              2392 non-null   int64
#  12  Volunteering       2392 non-null   int64
#  13  GPA                2392 non-null   float64
#  14  GradeClass         2392 non-null   float64
# dtypes: float64(3), int64(12)
# memory usage: 280.4 KB

# %%
df.shape
# Out:
# (2392, 15)

# %%
df.isnull().sum()
# Out:
# StudentID            0
# Age                  0
# Gender               0
# Ethnicity            0
# ParentalEducation    0
# StudyTimeWeekly      0
# Absences             0
# Tutoring             0
# ParentalSupport      0
# Extracurricular      0
# Sports               0
# Music                0
# Volunteering         0
# GPA                  0
# GradeClass           0
# dtype: int64

# %%
print(df.duplicated().sum())
# Out:
# 0

# %%
plt.figure(figsize=(25,6))
df.boxplot()
plt.title('All boxplots')
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.boxplot(x=df['ParentalEducation'])
plt.title('Boxplot of ParentalEducation')
plt.xlabel('ParentalEducation')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.boxplot(x=df['Music'])
plt.title('Boxplot of Music')
plt.xlabel('Music')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.boxplot(x=df['Volunteering'])
plt.title('Boxplot of Volunteering')
plt.xlabel('Volunteering')
plt.grid(True)
plt.show()

# %%
numerical_cols = ['ParentalEducation','Music','Volunteering']

# %%
def remove_outliers(df, column):

    q1 = df[column].quantile(0.25)
    q3 = df[column].quantile(0.75)
    iqr = q3 - q1

    lower = q1 - 1.5*iqr
    upper = q3 + 1.5*iqr
    
    return df[(df[column] >= lower) & (df[column] <= upper)]

# %%
for col in numerical_cols:
    df = remove_outliers(df, col)

# %%
df.shape
# Out:
# (1552, 15)

# %%
plt.figure(figsize=(25,6))
df.boxplot()
plt.title('All boxplots')
plt.show()

# %%
df.drop('StudentID', axis=1 ,inplace=True)

# %%
df.head()
# Out:
#    Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  Absences  \
# 1   18       0          0                  1        15.408756         0
# 2   15       0          2                  3         4.210570        26
# 3   17       1          0                  3        10.028829        14
# 4   17       1          0                  2         4.672495        17
# 5   18       0          0                  1         8.191219         0
#
#    Tutoring  ParentalSupport  Extracurricular  Sports  Music  Volunteering  \
# 1         0                1                0       0      0             0
# 2         0                2                0       0      0             0
# 3         0                3                1       0      0             0
# 4         1                3                0       0      0             0
# 5         0                1                1       0      0             0
#
#         GPA  GradeClass
# 1  3.042915         1.0
# 2  0.112602         4.0
# ...

# %%
X = df.drop(['GradeClass'], axis=1) 
df['GradeClass'] = df['GradeClass'].astype(int)
y = df['GradeClass']

# %%
X.head()
# Out:
#    Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  Absences  \
# 1   18       0          0                  1        15.408756         0
# 2   15       0          2                  3         4.210570        26
# 3   17       1          0                  3        10.028829        14
# 4   17       1          0                  2         4.672495        17
# 5   18       0          0                  1         8.191219         0
#
#    Tutoring  ParentalSupport  Extracurricular  Sports  Music  Volunteering  \
# 1         0                1                0       0      0             0
# 2         0                2                0       0      0             0
# 3         0                3                1       0      0             0
# 4         1                3                0       0      0             0
# 5         0                1                1       0      0             0
#
#         GPA
# 1  3.042915
# 2  0.112602
# 3  2.054218
# 4  1.288061
# 5  3.084184

# %%
y.head()
# Out:
# 1    1
# 2    4
# 3    3
# 4    4
# 5    1
# Name: GradeClass, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
X_train.head()
# Out:
#       Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  Absences  \
# 1018   18       1          0                  1         7.555936        22
# 2061   16       1          2                  1         2.010607        25
# 473    18       0          1                  2        11.836158        11
# 1531   16       0          0                  3        10.064384        28
# 845    15       0          3                  0        16.836174        10
#
#       Tutoring  ParentalSupport  Extracurricular  Sports  Music  Volunteering  \
# 1018         1                0                0       0      0             0
# 2061         0                2                1       1      0             0
# 473          1                3                1       1      0             0
# 1531         0                3                1       0      0             0
# 845          0                3                0       0      0             0
#
#            GPA
# 1018  0.968986
# ...

# %%
X_train.reset_index(inplace=True)
X_train.head()
# Out:
#    index  Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  \
# 0   1018   18       1          0                  1         7.555936
# 1   2061   16       1          2                  1         2.010607
# 2    473   18       0          1                  2        11.836158
# 3   1531   16       0          0                  3        10.064384
# 4    845   15       0          3                  0        16.836174
#
#    Absences  Tutoring  ParentalSupport  Extracurricular  Sports  Music  \
# 0        22         1                0                0       0      0
# 1        25         0                2                1       1      0
# 2        11         1                3                1       1      0
# 3        28         0                3                1       0      0
# 4        10         0                3                0       0      0
#
#    Volunteering       GPA
# 0             0  0.968986
# 1             0  0.665741
# 2             0  2.573034
# ...

# %%
X_train.drop('index', axis=1 , inplace=True)

# %%
X_train.head()
# Out:
#    Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  Absences  \
# 0   18       1          0                  1         7.555936        22
# 1   16       1          2                  1         2.010607        25
# 2   18       0          1                  2        11.836158        11
# 3   16       0          0                  3        10.064384        28
# 4   15       0          3                  0        16.836174        10
#
#    Tutoring  ParentalSupport  Extracurricular  Sports  Music  Volunteering  \
# 0         1                0                0       0      0             0
# 1         0                2                1       1      0             0
# 2         1                3                1       1      0             0
# 3         0                3                1       0      0             0
# 4         0                3                0       0      0             0
#
#         GPA
# 0  0.968986
# 1  0.665741
# 2  2.573034
# 3  0.741528
# 4  2.275700

# %%
X_train.shape
# Out:
# (1086, 13)

# %%
X_test.shape
# Out:
# (466, 13)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
features = ['Age', 'Gender', 'Ethnicity', 'ParentalEducation','StudyTimeWeekly','Absences','Tutoring','ParentalSupport','Extracurricular','Sports','Music','Volunteering','GPA']
X_train_scaled = scaler.fit_transform(X_train[features])

# %%
X_train_scaled = pd.DataFrame(X_train_scaled, columns=features)
X_train_scaled.head()
# Out:
#         Age    Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  \
# 0  1.362420  0.976339  -0.837686          -0.726398        -0.404359
# 1 -0.403198  0.976339   1.110338          -0.726398        -1.376090
# 2  1.362420 -1.024235   0.136326           0.410300         0.345682
# 3 -0.403198 -1.024235  -0.837686           1.546997         0.035206
# 4 -1.286007 -1.024235   2.084349          -1.863095         1.221855
#
#    Absences  Tutoring  ParentalSupport  Extracurricular    Sports  Music  \
# 0  0.856209  1.478090        -1.850421        -0.814305 -0.644908    0.0
# 1  1.205774 -0.676549        -0.089968         1.228040  1.550609    0.0
# 2 -0.425529  1.478090         0.790259         1.228040  1.550609    0.0
# 3  1.555339 -0.676549         0.790259         1.228040 -0.644908    0.0
# 4 -0.542051 -0.676549         0.790259        -0.814305 -0.644908    0.0
#
#    Volunteering       GPA
# 0           0.0 -0.979299
# 1           0.0 -1.307532
# 2           0.0  0.756931
# ...

# %%
X_test_scaled = scaler.fit_transform(X_test[features])

# %%
X_test_scaled = pd.DataFrame(X_test_scaled,columns=features)
X_test_scaled.head()
# Out:
#         Age    Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  \
# 0  0.513145  1.030508   2.074150           0.491521         0.812707
# 1  0.513145  1.030508  -0.884688           0.491521         1.507494
# 2 -0.389216 -0.970395   0.101591           0.491521         1.527542
# 3  0.513145 -0.970395   1.087870          -1.776287        -0.229295
# 4  0.513145  1.030508   0.101591           0.491521        -1.238773
#
#    Absences  Tutoring  ParentalSupport  Extracurricular    Sports  Music  \
# 0 -0.395808 -0.692362         1.674387        -0.761355 -0.729996    0.0
# 1  1.469644 -0.692362         0.782657        -0.761355  1.369870    0.0
# 2 -0.395808 -0.692362        -1.892536        -0.761355  1.369870    0.0
# 3 -0.978762  1.444331         0.782657         1.313448 -0.729996    0.0
# 4 -1.445125  1.444331        -1.000805        -0.761355 -0.729996    0.0
#
#    Volunteering       GPA
# 0           0.0  0.694619
# 1           0.0 -0.985093
# 2           0.0  0.164204
# ...

# %%
from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(X_train_scaled, y_train)
# Out:
# KNeighborsClassifier()

# %%
Knn_Predictions = knn.predict(X_test_scaled)
Knn_Predictions
# Out:
# array([3, 4, 3, 3, 3, 4, 4, 2, 2, 4, 4, 4, 2, 4, 2, 4, 2, 3, 4, 4, 2, 4,
#        4, 1, 4, 4, 2, 1, 4, 4, 4, 4, 4, 4, 4, 4, 4, 2, 2, 4, 3, 2, 2, 3,
#        4, 4, 3, 3, 4, 1, 0, 4, 4, 3, 4, 3, 4, 3, 4, 4, 4, 4, 3, 3, 4, 2,
#        3, 0, 4, 2, 2, 4, 4, 4, 0, 2, 3, 4, 4, 4, 4, 4, 2, 3, 4, 4, 3, 4,
#        4, 2, 4, 3, 4, 4, 4, 4, 3, 2, 1, 4, 4, 4, 0, 4, 4, 1, 4, 1, 4, 2,
#        3, 1, 1, 4, 4, 4, 3, 4, 4, 3, 2, 3, 3, 4, 4, 1, 3, 4, 2, 4, 4, 3,
#        2, 4, 1, 4, 2, 4, 1, 2, 4, 4, 1, 4, 4, 1, 4, 3, 4, 4, 2, 1, 2, 4,
#        4, 4, 4, 1, 4, 2, 4, 4, 3, 3, 2, 4, 4, 4, 2, 4, 4, 4, 4, 2, 4, 3,
#        4, 4, 4, 4, 3, 4, 1, 4, 4, 4, 4, 2, 1, 3, 2, 2, 4, 4, 4, 2, 3, 1,
#        3, 1, 4, 2, 3, 4, 2, 4, 4, 4, 3, 4, 4, 4, 4, 2, 4, 2, 4, 2, 4, 4,
#        4, 4, 4, 4, 2, 2, 1, 4, 4, 4, 4, 4, 2, 4, 3, 1, 4, 0, 4, 3, 2, 4,
#        2, 4, 2, 4, 3, 3, 3, 2, 2, 4, 4, 3, 2, 3, 4, 2, 1, 3, 4, 4, 1, 3,
#        3, 3, 4, 4, 1, 2, 4, 3, 3, 2, 3, 4, 1, 4, 4, 4, 4, 4, 1, 4, 4, 4,
# ...

# %%
pd.DataFrame(Knn_Predictions).value_counts()
# Out:
# 0
# 4    243
# 2     93
# 3     78
# 1     35
# 0     17
# Name: count, dtype: int64

# %%
pd.DataFrame(y_test).value_counts()
# Out:
# GradeClass
# 4             233
# 2              92
# 3              65
# 1              52
# 0              24
# Name: count, dtype: int64

# %%
from sklearn.metrics import accuracy_score

knn_accuracy = accuracy_score(y_test, Knn_Predictions)
print(f"Accuracy: {knn_accuracy:.2f}")
# Out:
# Accuracy: 0.63

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, Knn_Predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.24      0.17      0.20        24
#            1       0.43      0.29      0.34        52
#            2       0.46      0.47      0.46        92
#            3       0.29      0.35      0.32        65
#            4       0.85      0.89      0.87       233
#
#     accuracy                           0.63       466
#    macro avg       0.45      0.43      0.44       466
# weighted avg       0.62      0.63      0.62       466

# %%
df['GradeClass'].value_counts().plot(kind = 'bar', color = ['blue', 'red'])
# Out:
# <Axes: xlabel='GradeClass'>

# %%
class_percentage = df['GradeClass'].value_counts(normalize=True) * 100
print(class_percentage)
# Out:
# GradeClass
# 4    50.064433
# 2    17.203608
# 3    17.139175
# 1    10.760309
# 0     4.832474
# Name: proportion, dtype: float64

# %%
from imblearn.over_sampling import SMOTE
smote = SMOTE(random_state=42)

# %%
X, y = smote.fit_resample(X_train_scaled, y_train)
df_smote = pd.DataFrame(X)
df_smote['GradeClass'] = y
df_smote.head()
# Out:
#         Age    Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  \
# 0  1.362420  0.976339  -0.837686          -0.726398        -0.404359
# 1 -0.403198  0.976339   1.110338          -0.726398        -1.376090
# 2  1.362420 -1.024235   0.136326           0.410300         0.345682
# 3 -0.403198 -1.024235  -0.837686           1.546997         0.035206
# 4 -1.286007 -1.024235   2.084349          -1.863095         1.221855
#
#    Absences  Tutoring  ParentalSupport  Extracurricular    Sports  Music  \
# 0  0.856209  1.478090        -1.850421        -0.814305 -0.644908    0.0
# 1  1.205774 -0.676549        -0.089968         1.228040  1.550609    0.0
# 2 -0.425529  1.478090         0.790259         1.228040  1.550609    0.0
# 3  1.555339 -0.676549         0.790259         1.228040 -0.644908    0.0
# 4 -0.542051 -0.676549         0.790259        -0.814305 -0.644908    0.0
#
#    Volunteering       GPA  GradeClass
# 0           0.0 -0.979299           4
# ...

# %%
df_smote.shape
# Out:
# (2720, 14)

# %%
df.shape
# Out:
# (1552, 14)

# %%
df_smote['GradeClass'].value_counts().plot(kind = 'bar', color = ['blue', 'red'])
# Out:
# <Axes: xlabel='GradeClass'>

# %%
X = df_smote.drop(['GradeClass'], axis=1)
y = df_smote['GradeClass']

# %%
X.head()
# Out:
#         Age    Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  \
# 0  1.362420  0.976339  -0.837686          -0.726398        -0.404359
# 1 -0.403198  0.976339   1.110338          -0.726398        -1.376090
# 2  1.362420 -1.024235   0.136326           0.410300         0.345682
# 3 -0.403198 -1.024235  -0.837686           1.546997         0.035206
# 4 -1.286007 -1.024235   2.084349          -1.863095         1.221855
#
#    Absences  Tutoring  ParentalSupport  Extracurricular    Sports  Music  \
# 0  0.856209  1.478090        -1.850421        -0.814305 -0.644908    0.0
# 1  1.205774 -0.676549        -0.089968         1.228040  1.550609    0.0
# 2 -0.425529  1.478090         0.790259         1.228040  1.550609    0.0
# 3  1.555339 -0.676549         0.790259         1.228040 -0.644908    0.0
# 4 -0.542051 -0.676549         0.790259        -0.814305 -0.644908    0.0
#
#    Volunteering       GPA
# 0           0.0 -0.979299
# 1           0.0 -1.307532
# 2           0.0  0.756931
# ...

# %%
y.head()
# Out:
# 0    4
# 1    4
# 2    2
# 3    4
# 4    3
# Name: GradeClass, dtype: int64

# %%
models=['KNN','LR','SVM','DesicionTree','NaiveBayes','RandomForest']
scores=[]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
knn_Predictions = knn.predict(X_test)

# %%
from sklearn.metrics import accuracy_score

knn_accuracy = accuracy_score(y_test, knn_Predictions)
scores.append(knn_accuracy)
print(f"Accuracy: {knn_accuracy:.2f}")
# Out:
# Accuracy: 0.81

# %%
from sklearn.linear_model import LogisticRegression
LR = LogisticRegression()
LR.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
LR_pred = LR.predict(X_test)
LR_accuracy = accuracy_score(y_test, LR_pred)
scores.append(LR_accuracy)
print(f"Accuracy: {LR_accuracy:.2f}")
# Out:
# Accuracy: 0.57

# %%
print(classification_report(y_test, LR_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.52      0.68      0.59       152
#            1       0.72      0.50      0.59       170
#            2       0.41      0.45      0.43       158
#            3       0.52      0.45      0.48       165
#            4       0.70      0.76      0.73       171
#
#     accuracy                           0.57       816
#    macro avg       0.57      0.57      0.56       816
# weighted avg       0.58      0.57      0.57       816

# %%
from sklearn.svm import SVC

svm = SVC(kernel='linear', probability=True)
svm.fit(X_train, y_train)
# Out:
# SVC(kernel='linear', probability=True)

# %%
svm_pred = svm.predict(X_test)

# %%
svm_accuracy = accuracy_score(y_test, svm_pred)
scores.append(svm_accuracy)
print(f"Accuracy: {svm_accuracy:.2f}")
# Out:
# Accuracy: 0.74

# %%
print(classification_report(y_test, svm_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.58      0.72      0.64       152
#            1       0.88      0.62      0.73       170
#            2       0.86      0.59      0.70       158
#            3       0.78      0.94      0.85       165
#            4       0.72      0.83      0.77       171
#
#     accuracy                           0.74       816
#    macro avg       0.76      0.74      0.74       816
# weighted avg       0.77      0.74      0.74       816

# %%
from sklearn.tree import DecisionTreeClassifier

tree = DecisionTreeClassifier(max_depth=3, random_state=42)
tree.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=3, random_state=42)

# %%
tree_pred = tree.predict(X_test)

# %%
tree_accuracy = accuracy_score(y_test, tree_pred)
scores.append(tree_accuracy)
print(f"Accuracy: {tree_accuracy:.2f}")
# Out:
# Accuracy: 0.86

# %%
print(classification_report(y_test, tree_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.64      0.78       152
#            1       0.96      0.82      0.89       170
#            2       0.90      0.88      0.89       158
#            3       0.88      0.95      0.92       165
#            4       0.71      0.99      0.83       171
#
#     accuracy                           0.86       816
#    macro avg       0.89      0.86      0.86       816
# weighted avg       0.88      0.86      0.86       816

# %%
from sklearn.naive_bayes import GaussianNB

GNB = GaussianNB()
GNB.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
GNB_pred = GNB.predict(X_test)

# %%
GNB_accuracy = accuracy_score(y_test, GNB_pred)
scores.append(GNB_accuracy)
print(f"Accuracy: {GNB_accuracy:.2f}")
# Out:
# Accuracy: 0.72

# %%
print(classification_report(y_test, GNB_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.53      0.67       152
#            1       0.76      0.64      0.69       170
#            2       0.63      0.76      0.69       158
#            3       0.72      0.85      0.78       165
#            4       0.70      0.84      0.76       171
#
#     accuracy                           0.72       816
#    macro avg       0.75      0.72      0.72       816
# weighted avg       0.75      0.72      0.72       816

# %%
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier(n_estimators=100, random_state=42)
rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
rf_predictions = rf.predict(X_test)

# %%
rf_accuracy = accuracy_score(y_test, rf_predictions)
scores.append(rf_accuracy)
print(f"Accuracy: {rf_accuracy:.2f}")
# Out:
# Accuracy: 0.94

# %%
print(classification_report(y_test, rf_predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.92      0.96       152
#            1       0.97      0.91      0.94       170
#            2       0.97      0.90      0.93       158
#            3       0.93      0.98      0.95       165
#            4       0.85      0.98      0.91       171
#
#     accuracy                           0.94       816
#    macro avg       0.94      0.94      0.94       816
# weighted avg       0.94      0.94      0.94       816

# %%
models
# Out:
# ['KNN', 'LR', 'SVM', 'DesicionTree', 'NaiveBayes', 'RandomForest']

# %%
plt.figure(figsize=(10, 5))
plt.bar(models,scores)
# Out:
# <BarContainer object of 6 artists>
